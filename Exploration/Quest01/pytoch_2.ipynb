# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/AIFFEL_quest_rs/
# Out:
# /content/drive/MyDrive/AIFFEL_quest_rs

# %%
# !git restore Exploration/Quest01/colab_test.ipynb # 또는 git checkout Exploration/Quest01/colab_test.ipynb (구버전 Git)
# !git pull origin main
# Out:
# From https://github.com/nagujean/AIFFEL_quest_rs
#  * branch            main       -> FETCH_HEAD
# Updating c903d55..36ba7b3
# Fast-forward
#  .../.ipynb_checkpoints/colab_test-checkpoint.ipynb |    1 +
#  Exploration/Quest01/colab_test.ipynb               | 1118 +++++++++++++++++++-
#  Exploration/Quest01/models/model.pt                |  Bin 0 -> 2709 bytes
#  Exploration/Quest01/models/model_state_dict.pt     |  Bin 0 -> 2029 bytes
#  Exploration/Quest01/non_linear.csv                 |  201 ++++
#  5 files changed, 1319 insertions(+), 1 deletion(-)
#  create mode 100644 Exploration/Quest01/.ipynb_checkpoints/colab_test-checkpoint.ipynb
#  create mode 100644 Exploration/Quest01/models/model.pt
#  create mode 100644 Exploration/Quest01/models/model_state_dict.pt
#  create mode 100644 Exploration/Quest01/non_linear.csv

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 2), reused 10 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 9.64 KiB | 14.00 KiB/s, done.
# From https://github.com/nagujean/AIFFEL_quest_rs
#  * branch            main       -> FETCH_HEAD
#    c903d55..36ba7b3  main       -> origin/main
# Updating c903d55..36ba7b3
# error: Your local changes to the following files would be overwritten by merge:
# 	Exploration/Quest01/colab_test.ipynb
# Please commit your changes or stash them before you merge.
# Aborting

# %%
import os
print(os.getcwd())
# Out:
# /content/drive/MyDrive/AIFFEL_quest_rs

# %%
# %cd /content/drive/MyDrive/AIFFEL_quest_rs/Exploration/Quest01/
# Out:
# /content/drive/MyDrive/AIFFEL_quest_rs/Exploration/Quest01

# %%
# !ls
# Out:
# colab_test.ipynb  non_linear.csv  Quest01.ipynb
# models		  pytoch_2.ipynb  README.md

# %%
import torch
from torch import nn


class CustomModel(nn.Module):
    pass

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = torch.load("./models/model.pt", map_location=device, weights_only=False) # weights_only=False 추가
print(model)
# Out:
# CustomModel(
#   (layer): Linear(in_features=2, out_features=1, bias=True)
# )
