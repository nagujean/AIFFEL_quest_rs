# %%
# 교제 07_트랜스포머 예제

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.55.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Downloading huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.12/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.12/site-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.7.34-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from transformers) (2.32.4)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.12/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Downloading hf_xet-1.1.7-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (703 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->transformers) (2025.6.15)
# Downloading transformers-4.55.0-py3-none-any.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 32.2 MB/s eta 0:00:00a 0:00:01
# Downloading huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 32.6 MB/s eta 0:00:00
# Downloading hf_xet-1.1.7-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 131.6 MB/s eta 0:00:00
# Downloading tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 117.1 MB/s eta 0:00:00
# Downloading regex-2025.7.34-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.9/801.9 kB 44.0 MB/s eta 0:00:00
# Downloading safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Installing collected packages: safetensors, regex, hf-xet, huggingface-hub, tokenizers, transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [transformers] [transformers]ub]
# Successfully installed hf-xet-1.1.7 huggingface-hub-0.34.4 regex-2025.7.34 safetensors-0.6.2 tokenizers-0.21.4 transformers-4.55.0

# %%
# 코드 전체의 목적: GPT-2 모델의 계층적인 구조를 출력합니다.
from transformers import GPT2LMHeadModel # 1. huggingface의 transformers 라이브러리에서 GPT2LMHeadModel 클래스를 가져옵니다.

model = GPT2LMHeadModel.from_pretrained(pretrained_model_name_or_path="gpt2") # 2. 'gpt2'라는 이름의 사전 학습된 모델을 로드하여 model 변수에 할당합니다.

for main_name, main_module in model.named_children(): # 3. model의 직접적인 자식 모듈(최상위 계층)을 순회합니다. main_name은 모듈의 이름, main_module은 모듈 자체입니다.
    print(main_name) # 4. 최상위 모듈의 이름을 출력합니다.
    for sub_name, sub_module in main_module.named_children(): # 5. 각 최상위 모듈의 자식 모듈을 순회합니다.
        print("└", sub_name) # 6. 자식 모듈의 이름을 출력합니다. (계층을 나타내기 위해 "└" 기호를 사용합니다.)
        for ssub_name, ssub_module in sub_module.named_children(): # 7. 각 자식 모듈의 자식 모듈을 순회합니다.
            print("│  └", ssub_name) # 8. 손자 모듈의 이름을 출력합니다.
            for sssub_name, sssub_module in ssub_module.named_children(): # 9. 각 손자 모듈의 자식 모듈을 순회합니다.
                print("│  │  └", sssub_name) # 10. 증손자 모듈의 이름을 출력합니다.
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# transformer
# └ wte
# └ wpe
# └ drop
# └ h
# │  └ 0
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 1
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 2
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 3
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 4
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 5
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 6
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 7
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 8
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 9
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 10
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# │  └ 11
# │  │  └ ln_1
# │  │  └ attn
# │  │  └ ln_2
# │  │  └ mlp
# └ ln_f
# lm_head

# %%
# 코드 전체의 목적: 사전 학습된 GPT-2 모델을 사용하여 텍스트를 생성하는 파이프라인을 구축하고 실행합니다.
from transformers import pipeline # 1. huggingface의 transformers 라이브러리에서 pipeline 클래스를 가져옵니다.

generator = pipeline(task="text-generation", model="gpt2") # 2. 'text-generation' 태스크를 수행할 파이프라인을 생성하고, 사용할 모델로 'gpt2'를 지정합니다.

outputs = generator( # 3. 생성된 파이프라인을 호출하여 텍스트를 생성합니다.
    text_inputs="Machine learning is", # 4. 생성의 시작점이 될 입력 텍스트를 지정합니다.
    max_length=20, # 5. 생성될 텍스트의 최대 길이를 20 토큰으로 제한합니다.
    num_return_sequences=3, # 6. 3개의 서로 다른 결과물을 생성하도록 지정합니다.
    pad_token_id=generator.tokenizer.eos_token_id) # 7. 모델이 텍스트 생성의 끝을 알리는 토큰(end-of-sequence)을 패딩 토큰으로 사용하도록 설정합니다.

print(outputs) # 8. 생성된 텍스트 결과물을 출력합니다.
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Machine learning is a major part of AI, and it's one of those areas that has been very good at getting very good at predicting what you're going to do for a long time.\n\nIs there still a future for AI?\n\nThere's a lot of talk of AI as a part of the future. There's a lot of talk of AI making new kinds of connections. There's a lot of talk that AI is going to be part of the future. It's always been on the rise but there's a lot of talk about how it's going to be part of the future. To me, it's more about the future than it is of the past. I think we're going to see a lot of AI be part of the future.\n\nWhat's your thinking on the future of AI?\n\nThere's a lot of talk about AI being part of the future, and that is really exciting. I don't think there's a future in that sense, but I do think there's a future in that sense of the past.\n\nWhat's your favorite thing about AI?\n\nThe best thing about it is that it is so much smarter. The best thing about it is that it's so much more intelligent. You see a bunch"}, {'generated_text': 'Machine learning is a topic in which the field of neuroscience is a part. The current method of neuroscience can be applied to any field of neuroscience, and the results of this paper are quite exciting.\n\nThe current field of neuroscience is the field of genetics, though the general definition of the term "genetic" is not very common. The term is often used in a variety of ways: there are many genetic differences between people, there are different kinds of people, there are different kinds of genetic mutations, and there are different kinds of differences in how a person interacts with others. However, all of this has been well known for a very long time, and the science of genetics is a part of that. The field of neuroscience is also known for its ability to identify common genetic mutations, and what that can tell us about how we can better understand a disease.\n\nThe key concept here is that the genetic basis of a disease is the way that a person interacts with the environment. The disease itself is a problem of understanding how a person interacts with the environment. This is a common misconception, because it is a common misconception that genes and proteins play a role in disease. However, most of the time, the disease itself is not a problem of understanding how a person interacts with the'}, {'generated_text': 'Machine learning is a process of using data to learn from other systems, so learning from the past is often more powerful. Here are five examples of how to use neural networks to learn.\n\n1. Learning from your past\n\nYou\'re probably familiar with using deep learning — it\'s a process by which you learn to understand and recognize the past. But how do you get there?\n\nHow do you know when you did something right?\n\nYou might be surprised to learn that you did something wrong.\n\nThis is where neural networks come in — they\'re a part of your brain that learns and learns. But most people don\'t use them in a productive way.\n\nIf you use neural networks to learn how to solve a problem, instead of using them to learn from your past, you\'re essentially losing your performance.\n\nSo, it\'s important to understand when you do something right.\n\n2. Learning from your past\n\nYou might be shocked to learn that you did something wrong, but you actually do.\n\nWhen you learn from your past, you\'re learning things that other people don\'t.\n\n"I don\'t know who made those things," you might say. But in most cases, you\'re just learning from experience.'}]

# %%
# Colab 환경에 맞는 torch 버전을 확인하고 torchtext를 설치
#!pip install torchtext==0.18.0 torch==2.3.0
# Out:
# Requirement already satisfied: torchtext==0.18.0 in /usr/local/lib/python3.11/dist-packages (0.18.0)
# Requirement already satisfied: torch==2.3.0 in /usr/local/lib/python3.11/dist-packages (2.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.18.0) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (4.14.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.3.0) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0) (12.5.82)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.3.0) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.18.0) (2025.7.14)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.3.0) (1.3.0)

# %%
# !pip uninstall torchtext torch -y
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Found existing installation: torchtext 0.18.0
# Uninstalling torchtext-0.18.0:
#   Successfully uninstalled torchtext-0.18.0
# Found existing installation: torch 2.7.1+cu118
# Uninstalling torch-2.7.1+cu118:

# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.12/site-packages (2.7.1+cu118)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.12/site-packages (0.22.1+cu118)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch) (4.14.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /opt/conda/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/conda/lib/python3.12/site-packages (from torch) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.12/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/conda/lib/python3.12/site-packages (from torch) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/conda/lib/python3.12/site-packages (from torch) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/conda/lib/python3.12/site-packages (from torch) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /opt/conda/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/conda/lib/python3.12/site-packages (from torch) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.12/site-packages (from torch) (3.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.12/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install torchdata
# Out:
# Collecting torchdata
#   Downloading torchdata-0.11.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: urllib3>=1.25 in /opt/conda/lib/python3.12/site-packages (from torchdata) (2.4.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from torchdata) (2.32.4)
# Requirement already satisfied: torch>=2 in /opt/conda/lib/python3.12/site-packages (from torchdata) (2.7.1+cu118)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (4.14.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (1.14.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (3.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (3.1.6)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.8.89)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.8.89 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.8.89)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.8.87 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.8.87)
# Requirement already satisfied: nvidia-cudnn-cu11==9.1.0.70 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu11==11.11.3.6 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.11.3.6)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.3.0.86 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (10.3.0.86)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.1.48 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.4.1.48)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.5.86 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.7.5.86)
# Requirement already satisfied: nvidia-nccl-cu11==2.21.5 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu11==11.8.86 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (11.8.86)
# Requirement already satisfied: triton==3.3.1 in /opt/conda/lib/python3.12/site-packages (from torch>=2->torchdata) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2->torchdata) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->torch>=2->torchdata) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->torchdata) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->torchdata) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests->torchdata) (2025.6.15)
# Downloading torchdata-0.11.0-py3-none-any.whl (61 kB)
# Installing collected packages: torchdata
# Successfully installed torchdata-0.11.0

# %%
# 1. 라이브러리 및 데이터셋 준비
import torch
from torchtext.datasets import CoLA
from transformers import AutoTokenizer
from torch.utils.data import DataLoader

# 2. 데이터 처리 함수
def collator(batch, tokenizer, device): # collator 함수 정의
    source, labels, texts = zip(*batch) # batch 데이터를 source, labels, texts로 언패킹
    tokenized = tokenizer( # texts를 토큰화하고 패딩/절단 처리
        texts,
        padding="longest", # 가장 긴 문장을 기준으로 패딩
        truncation=True, # 모델 최대 길이 초과 시 절단
        return_tensors="pt" # PyTorch 텐서로 반환
    )
    input_ids = tokenized["input_ids"].to(device) # input_ids를 device(GPU/CPU)로 이동
    attention_mask = tokenized["attention_mask"].to(device) # attention_mask를 device로 이동
    labels = torch.tensor(labels, dtype=torch.long).to(device) # labels를 텐서로 변환하여 device로 이동
    return input_ids, attention_mask, labels # 처리된 데이터 반환

# 3. 데이터셋 로드 및 토크나이저 설정
train_data = list(CoLA(split="train")) # CoLA 학습 데이터 로드
valid_data = list(CoLA(split="dev")) # CoLA 검증 데이터 로드
test_data = list(CoLA(split="test")) # CoLA 테스트 데이터 로드
tokenizer = AutoTokenizer.from_pretrained("gpt2") # gpt2 토크나이저 불러오기
tokenizer.pad_token = tokenizer.eos_token # 패딩 토큰을 eos 토큰으로 설정

# 4. 하이퍼파라미터 및 데이터로더 설정
epochs = 3 # 총 3 에폭 학습
batch_size = 16 # 배치 크기 설정
device = "cuda" if torch.cuda.is_available() else "cpu" # GPU 사용 가능 여부 확인
train_dataloader = DataLoader( # 학습 데이터로더 생성
    train_data,
    batch_size=batch_size,
    collate_fn=lambda x: collator(x, tokenizer, device), # collator 함수 적용
    shuffle=True,) # 데이터 셔플
valid_dataloader = DataLoader( # 검증 데이터로더 생성
    valid_data, batch_size=batch_size, collate_fn=lambda x: collator(x, tokenizer, device)) # collator 함수 적용
test_dataloader = DataLoader( # 테스트 데이터로더 생성
    test_data, batch_size=batch_size, collate_fn=lambda x: collator(x, tokenizer, device)) # collator 함수 적용
print("Train Dataset Length :", len(train_data)) # 데이터셋 크기 출력
print("Valid Dataset Length :", len(valid_data))
print("Test Dataset Length :", len(test_data))


# 5. 모델 및 옵티마이저 설정
from torch import optim
from transformers import GPT2ForSequenceClassification
model = GPT2ForSequenceClassification.from_pretrained( # GPT2 모델 불러오기
    pretrained_model_name_or_path="gpt2",
    num_labels=2).to(device) # 2개의 라벨(문법적/비문법적)로 분류하도록 설정
model.config.pad_token_id = model.config.eos_token_id # 모델의 패딩 토큰 ID 설정
optimizer = optim.Adam(model.parameters(), lr=5e-5) # Adam 옵티마이저 사용, 학습률 5e-5


# 6. 학습 및 평가 함수
import numpy as np
from torch import nn
def calc_accuracy(preds, labels): # 정확도 계산 함수 정의
    pred_flat = np.argmax(preds, axis=1).flatten() # 예측값을 1차원 배열로 변환
    labels_flat = labels.flatten() # 라벨을 1차원 배열로 변환
    return np.sum(pred_flat == labels_flat) / len(labels_flat) # 정확도 반환

def train(model, optimizer, dataloader): # 학습 함수 정의
    model.train() # 모델을 학습 모드로 전환
    train_loss = 0.0

    for input_ids, attention_mask, labels in dataloader:
        outputs = model( # 모델에 데이터 입력
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )
        loss = outputs.loss # 손실(loss) 계산
        train_loss += loss.item() # 누적 손실 계산
        optimizer.zero_grad() # 그래디언트 초기화
        loss.backward() # 역전파
        optimizer.step() # 옵티마이저를 통해 가중치 업데이트

    train_loss = train_loss / len(dataloader) # 평균 손실 계산
    return train_loss

def evaluation(model, dataloader): # 평가 함수 정의
    with torch.no_grad(): # 그래디언트 계산 비활성화
        model.eval() # 모델을 평가 모드로 전환
        val_loss, val_accuracy = 0.0, 0.0

        for input_ids, attention_mask, labels in dataloader:
            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels
            )
            logits = outputs.logits # 예측값(logits) 가져오기
            loss = outputs.loss # 손실(loss) 계산
            logits = logits.detach().cpu().numpy() # 텐서를 CPU로 이동 후 numpy로 변환
            label_ids = labels.to("cpu").numpy() # 라벨을 CPU로 이동 후 numpy로 변환
            accuracy = calc_accuracy(logits, label_ids) # 정확도 계산
            val_loss += loss.item() # 누적 손실 계산
            val_accuracy += accuracy # 누적 정확도 계산

    val_loss = val_loss/len(dataloader) # 평균 손실 계산
    val_accuracy = val_accuracy/len(dataloader) # 평균 정확도 계산
    return val_loss, val_accuracy


# 7. 모델 학습 및 저장
best_loss = 10000
for epoch in range(epochs):
    train_loss = train(model, optimizer, train_dataloader) # 학습 함수 호출
    val_loss, val_accuracy = evaluation(model, valid_dataloader) # 평가 함수 호출
    print(f"Epoch {epoch + 1}: Train Loss: {train_loss:.4f} Val Loss: {val_loss:.4f} Val Accuracy {val_accuracy:.4f}")

    if val_loss < best_loss: # 손실이 감소했을 경우
        best_loss = val_loss
        torch.save(model.state_dict(), "../models/GPT2ForSequenceClassification.pt") # 모델 가중치 저장
        print("Saved the model weights")

# 8. 테스트 데이터셋으로 최종 평가
model = GPT2ForSequenceClassification.from_pretrained(
    pretrained_model_name_or_path="gpt2",
    num_labels=2).to(device)
model.config.pad_token_id = model.config.eos_token_id
model.load_state_dict(torch.load("../models/GPT2ForSequenceClassification.pt")) # 저장된 가중치 불러오기
test_loss, test_accuracy = evaluation(model, test_dataloader) # 테스트 데이터로 최종 평가
print(f"Test Loss : {test_loss:.4f}")
print(f"Test Accuracy : {test_accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 1. 라이브러리 및 데이터셋 준비
#       2 import torch
# ----> 3 from torchtext.datasets import CoLA
#       4 from transformers import AutoTokenizer
#       5 from torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'torchtext'

# %%
# %cd /content/drive/MyDrive/AIFFEL_quest_rs/Exploration/Quest01/
# !ls
# Out:
# /content/drive/MyDrive/AIFFEL_quest_rs/Exploration/Quest01
# colab_test.ipynb  pytoch_4.ipynb
# data		  pytoch_5_DatdAug.ipynb
# datasets	  pytoch_6_ImgClassification.ipynb
# etc_teat	  pytoch_7.ipynb
# models		  pytoch_8_TextDataPreProcessing.ipynb
# non_linear.csv	  pytorch_1.ipynb
# Pokemon.csv	  Quest01.ipynb
# pytoch_2.ipynb	  README.md
# pytoch_3.ipynb

# %%
# !git config --global user.email "nagujean@gmail.com"

# %%
# !git config --global user.name "nagujean"

# %%
# !git add .

# %%
# !git commit -m "commit"
# Out:
# [main 196b956] commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin main
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1.22 KiB | 83.00 KiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/nagujean/AIFFEL_quest_rs.git
#    6a84ff7..196b956  main -> main

# %%
# !git config --global credential.helper manager

# %%
# !git config --global credential.helper store

# %%
# !git config --global --unset credential.helper

# %%
# !git remote set-url origin https://github.com/nagujean/AIFFEL_quest_rs.git

# %%
# !git reset --soft HEAD~1

# %%
# !git push -f origin main
# Out:
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 3.28 KiB | 239.00 KiB/s, done.
# Total 12 (delta 8), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (8/8), completed with 4 local objects.
# To https://github.com/nagujean/AIFFEL_quest_rs.git
#    e95a5a6..a33cac5  main -> main

# %%
# 깃허브 토큰 변경 후 오류 발생
 #푸시에서 최초 오류 발생
 #커밋된 내용이 중복으로 되어 있어 낌
 #푸시에서 이름 입력창이 나오지 않고 리모트 오류 나옴
 #해결방안
  #깃허브 사용자명과 토큰을 직접 입력해야하지만 그러면 깃허브 보안때문에 다시 푸시에서 문제가 생김
  #좌측 열쇠 아이콘을 열여 시크릿 기능으로 토큰 값을 저장해둠
  #저장된 토큰을 값으로 변수 설정
  #토큰이 저장된 변수 명을 사용하여 입력
  #푸시


from google.colab import userdata
import os

# 1. Secrets에서 GITHUB_TOKEN 값을 가져옵니다.
github_token = userdata.get('GITHUB_TOKEN')

# 2. Python f-string을 사용하여 전체 Git 명령어를 만듭니다.
git_command = f"git remote set-url origin https://nagujean:{github_token}@github.com/nagujean/AIFFEL_quest_rs.git"

# 3. 콜랩 쉘에서 해당 명령어를 실행합니다.
# !git push origin main
